# %% [markdown]
# <a href="https://colab.research.google.com/github/programacaodinamica/analise-dados/blob/master/Eleicoes_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conjuntos de dados disponíveis aqui:
# https://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1/repositorio-de-dados-eleitorais

# %% [markdown]
# ### **Importando os dados**

# %%
import pandas as pd
import seaborn as sns

# %%
sns.set()

# %%
cand_BRASIL = pd.read_csv("/content/drive/My Drive/Colab Datasets/eleicoes/consulta_cand_2020_BRASIL.csv", sep=';', encoding='iso-8859-1')

# %%
cand_BRASIL
# Out:
#         DT_GERACAO  ... ST_CANDIDATO_INSERIDO_URNA
# 0       05/10/2020  ...                        NÃO
# 1       05/10/2020  ...                        NÃO
# 2       05/10/2020  ...                        NÃO
# 3       05/10/2020  ...                        NÃO
# 4       05/10/2020  ...                        NÃO
# ...            ...  ...                        ...
# 551465  05/10/2020  ...                        NÃO
# 551466  05/10/2020  ...                        NÃO
# 551467  05/10/2020  ...                        NÃO
# 551468  05/10/2020  ...                        NÃO
# 551469  05/10/2020  ...                        NÃO
#
# [551470 rows x 63 columns]

# %%
cand_BRASIL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551470 entries, 0 to 551469
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DT_GERACAO                     551470 non-null  object
#  1   HH_GERACAO                     551470 non-null  object
#  2   ANO_ELEICAO                    551470 non-null  int64
#  3   CD_TIPO_ELEICAO                551470 non-null  int64
#  4   NM_TIPO_ELEICAO                551470 non-null  object
#  5   NR_TURNO                       551470 non-null  int64
#  6   CD_ELEICAO                     551470 non-null  int64
#  7   DS_ELEICAO                     551470 non-null  object
#  8   DT_ELEICAO                     551470 non-null  object
#  9   TP_ABRANGENCIA                 551470 non-null  object
#  10  SG_UF                          551470 non-null  object
#  11  SG_UE                          551470 non-null  int64
#  12  NM_UE                          551470 non-null  object
#  13  CD_CARGO                       551470 non-null  int64
#  14  DS_CARGO                       551470 non-null  object
#  15  SQ_CANDIDATO                   551470 non-null  int64
#  16  NR_CANDIDATO                   551470 non-null  int64
#  17  NM_CANDIDATO                   551470 non-null  object
#  18  NM_URNA_CANDIDATO              551467 non-null  object
#  19  NM_SOCIAL_CANDIDATO            551470 non-null  object
#  20  NR_CPF_CANDIDATO               551470 non-null  int64
#  21  NM_EMAIL                       551470 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        551470 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        551470 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       551470 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       551470 non-null  object
#  26  TP_AGREMIACAO                  551470 non-null  object
#  27  NR_PARTIDO                     551470 non-null  int64
#  28  SG_PARTIDO                     551470 non-null  object
#  29  NM_PARTIDO                     551470 non-null  object
#  30  SQ_COLIGACAO                   551470 non-null  int64
#  31  NM_COLIGACAO                   551470 non-null  object
#  32  DS_COMPOSICAO_COLIGACAO        551470 non-null  object
#  33  CD_NACIONALIDADE               551470 non-null  int64
#  34  DS_NACIONALIDADE               551470 non-null  object
#  35  SG_UF_NASCIMENTO               551470 non-null  object
#  36  CD_MUNICIPIO_NASCIMENTO        551470 non-null  int64
#  37  NM_MUNICIPIO_NASCIMENTO        551470 non-null  object
#  38  DT_NASCIMENTO                  551470 non-null  object
#  39  NR_IDADE_DATA_POSSE            551470 non-null  int64
#  40  NR_TITULO_ELEITORAL_CANDIDATO  551470 non-null  int64
#  41  CD_GENERO                      551470 non-null  int64
#  42  DS_GENERO                      551470 non-null  object
#  43  CD_GRAU_INSTRUCAO              551470 non-null  int64
#  44  DS_GRAU_INSTRUCAO              551470 non-null  object
#  45  CD_ESTADO_CIVIL                551470 non-null  int64
#  46  DS_ESTADO_CIVIL                551470 non-null  object
#  47  CD_COR_RACA                    551470 non-null  int64
#  48  DS_COR_RACA                    551470 non-null  object
#  49  CD_OCUPACAO                    551470 non-null  int64
#  50  DS_OCUPACAO                    551470 non-null  object
#  51  VR_DESPESA_MAX_CAMPANHA        551470 non-null  int64
#  52  CD_SIT_TOT_TURNO               551470 non-null  int64
#  53  DS_SIT_TOT_TURNO               551470 non-null  object
#  54  ST_REELEICAO                   551470 non-null  object
#  55  ST_DECLARAR_BENS               551470 non-null  object
#  56  NR_PROTOCOLO_CANDIDATURA       551470 non-null  int64
#  57  NR_PROCESSO                    551470 non-null  int64
#  58  CD_SITUACAO_CANDIDATO_PLEITO   551470 non-null  int64
#  59  DS_SITUACAO_CANDIDATO_PLEITO   551470 non-null  object
#  60  CD_SITUACAO_CANDIDATO_URNA     551470 non-null  int64
#  61  DS_SITUACAO_CANDIDATO_URNA     551470 non-null  object
#  62  ST_CANDIDATO_INSERIDO_URNA     551470 non-null  object
# dtypes: int64(28), object(35)
# memory usage: 265.1+ MB

# %%
cand_BRASIL[cand_BRASIL['NM_URNA_CANDIDATO'].str.contains('BOLSONARO') == True]
# Out:
#         DT_GERACAO  ... ST_CANDIDATO_INSERIDO_URNA
# 1448    05/10/2020  ...                        NÃO
# 2084    05/10/2020  ...                        NÃO
# 5091    05/10/2020  ...                        NÃO
# 6925    05/10/2020  ...                        NÃO
# 12329   05/10/2020  ...                        NÃO
# ...            ...  ...                        ...
# 533617  05/10/2020  ...                        NÃO
# 536853  05/10/2020  ...                        NÃO
# 538472  05/10/2020  ...                        NÃO
# 542050  05/10/2020  ...                        NÃO
# 542238  05/10/2020  ...                        NÃO
#
# [91 rows x 63 columns]

# %%
cand_BRASIL['ST_REELEICAO'].value_counts(normalize=True)*100
# Out:
# N    95.839846
# S     4.160154
# Name: ST_REELEICAO, dtype: float64

# %%
cand_BRASIL['DS_GRAU_INSTRUCAO'].value_counts(normalize=True)
# Out:
# ENSINO MÉDIO COMPLETO            0.381065
# SUPERIOR COMPLETO                0.243346
# ENSINO FUNDAMENTAL INCOMPLETO    0.127739
# ENSINO FUNDAMENTAL COMPLETO      0.122003
# ENSINO MÉDIO INCOMPLETO          0.049627
# SUPERIOR INCOMPLETO              0.044753
# LÊ E ESCREVE                     0.031431
# ANALFABETO                       0.000036
# Name: DS_GRAU_INSTRUCAO, dtype: float64

# %%
cand_BRASIL['DS_GRAU_INSTRUCAO'].value_counts(normalize=True).plot(kind='bar', title='Grau de Instrucao Candidatos 2020');

# %%
(100*cand_BRASIL['SG_PARTIDO'].value_counts(normalize=True)).plot(kind='bar', figsize=(12,6), title='Candidados por Partido 2020')

# %%
cand_RJ = pd.read_csv("/content/drive/My Drive/Colab Datasets/eleicoes/consulta_cand_2020_RJ.csv", sep=';', encoding='iso-8859-1')

# %%
cand_RJ
# Out:
#        DT_GERACAO  ... ST_CANDIDATO_INSERIDO_URNA
# 0      05/10/2020  ...                        NÃO
# 1      05/10/2020  ...                        NÃO
# 2      05/10/2020  ...                        NÃO
# 3      05/10/2020  ...                        NÃO
# 4      05/10/2020  ...                        NÃO
# ...           ...  ...                        ...
# 26189  05/10/2020  ...                        NÃO
# 26190  05/10/2020  ...                        NÃO
# 26191  05/10/2020  ...                        NÃO
# 26192  05/10/2020  ...                        NÃO
# 26193  05/10/2020  ...                        NÃO
#
# [26194 rows x 63 columns]

# %%
cand_RJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26194 entries, 0 to 26193
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     26194 non-null  object
#  1   HH_GERACAO                     26194 non-null  object
#  2   ANO_ELEICAO                    26194 non-null  int64
#  3   CD_TIPO_ELEICAO                26194 non-null  int64
#  4   NM_TIPO_ELEICAO                26194 non-null  object
#  5   NR_TURNO                       26194 non-null  int64
#  6   CD_ELEICAO                     26194 non-null  int64
#  7   DS_ELEICAO                     26194 non-null  object
#  8   DT_ELEICAO                     26194 non-null  object
#  9   TP_ABRANGENCIA                 26194 non-null  object
#  10  SG_UF                          26194 non-null  object
#  11  SG_UE                          26194 non-null  int64
#  12  NM_UE                          26194 non-null  object
#  13  CD_CARGO                       26194 non-null  int64
#  14  DS_CARGO                       26194 non-null  object
#  15  SQ_CANDIDATO                   26194 non-null  int64
#  16  NR_CANDIDATO                   26194 non-null  int64
#  17  NM_CANDIDATO                   26194 non-null  object
#  18  NM_URNA_CANDIDATO              26194 non-null  object
#  19  NM_SOCIAL_CANDIDATO            26194 non-null  object
#  20  NR_CPF_CANDIDATO               26194 non-null  int64
#  21  NM_EMAIL                       26194 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        26194 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        26194 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       26194 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       26194 non-null  object
#  26  TP_AGREMIACAO                  26194 non-null  object
#  27  NR_PARTIDO                     26194 non-null  int64
#  28  SG_PARTIDO                     26194 non-null  object
#  29  NM_PARTIDO                     26194 non-null  object
#  30  SQ_COLIGACAO                   26194 non-null  int64
#  31  NM_COLIGACAO                   26194 non-null  object
#  32  DS_COMPOSICAO_COLIGACAO        26194 non-null  object
#  33  CD_NACIONALIDADE               26194 non-null  int64
#  34  DS_NACIONALIDADE               26194 non-null  object
#  35  SG_UF_NASCIMENTO               26194 non-null  object
#  36  CD_MUNICIPIO_NASCIMENTO        26194 non-null  int64
#  37  NM_MUNICIPIO_NASCIMENTO        26194 non-null  object
#  38  DT_NASCIMENTO                  26194 non-null  object
#  39  NR_IDADE_DATA_POSSE            26194 non-null  int64
#  40  NR_TITULO_ELEITORAL_CANDIDATO  26194 non-null  int64
#  41  CD_GENERO                      26194 non-null  int64
#  42  DS_GENERO                      26194 non-null  object
#  43  CD_GRAU_INSTRUCAO              26194 non-null  int64
#  44  DS_GRAU_INSTRUCAO              26194 non-null  object
#  45  CD_ESTADO_CIVIL                26194 non-null  int64
#  46  DS_ESTADO_CIVIL                26194 non-null  object
#  47  CD_COR_RACA                    26194 non-null  int64
#  48  DS_COR_RACA                    26194 non-null  object
#  49  CD_OCUPACAO                    26194 non-null  int64
#  50  DS_OCUPACAO                    26194 non-null  object
#  51  VR_DESPESA_MAX_CAMPANHA        26194 non-null  int64
#  52  CD_SIT_TOT_TURNO               26194 non-null  int64
#  53  DS_SIT_TOT_TURNO               26194 non-null  object
#  54  ST_REELEICAO                   26194 non-null  object
#  55  ST_DECLARAR_BENS               26194 non-null  object
#  56  NR_PROTOCOLO_CANDIDATURA       26194 non-null  int64
#  57  NR_PROCESSO                    26194 non-null  int64
#  58  CD_SITUACAO_CANDIDATO_PLEITO   26194 non-null  int64
#  59  DS_SITUACAO_CANDIDATO_PLEITO   26194 non-null  object
#  60  CD_SITUACAO_CANDIDATO_URNA     26194 non-null  int64
#  61  DS_SITUACAO_CANDIDATO_URNA     26194 non-null  object
#  62  ST_CANDIDATO_INSERIDO_URNA     26194 non-null  object
# dtypes: int64(28), object(35)
# memory usage: 12.6+ MB

# %%
cand_RJ['ST_REELEICAO'].value_counts(normalize=True)*100
# Out:
# N    97.984271
# S     2.015729
# Name: ST_REELEICAO, dtype: float64

# %%
cand_RJ[cand_RJ['SG_PARTIDO']=='MDB']['DS_GRAU_INSTRUCAO'].value_counts(normalize=True)*100
# Out:
# ENSINO MÉDIO COMPLETO            40.945584
# SUPERIOR COMPLETO                21.141838
# ENSINO FUNDAMENTAL COMPLETO      13.380910
# ENSINO FUNDAMENTAL INCOMPLETO    12.310437
# ENSINO MÉDIO INCOMPLETO           5.530776
# SUPERIOR INCOMPLETO               5.263158
# LÊ E ESCREVE                      1.427297
# Name: DS_GRAU_INSTRUCAO, dtype: float64

# %%
cand_RJ[cand_RJ['SG_PARTIDO']=='PSOL']['DS_GRAU_INSTRUCAO'].value_counts(normalize=True)*100
# Out:
# SUPERIOR COMPLETO                44.897959
# ENSINO MÉDIO COMPLETO            31.122449
# SUPERIOR INCOMPLETO               8.673469
# ENSINO FUNDAMENTAL INCOMPLETO     6.887755
# ENSINO FUNDAMENTAL COMPLETO       4.081633
# ENSINO MÉDIO INCOMPLETO           3.571429
# LÊ E ESCREVE                      0.765306
# Name: DS_GRAU_INSTRUCAO, dtype: float64

# %%
cand_RJ[cand_RJ['SG_PARTIDO']=='NOVO']['DS_GRAU_INSTRUCAO'].value_counts(normalize=True)*100
# Out:
# SUPERIOR COMPLETO              86.885246
# SUPERIOR INCOMPLETO             6.557377
# ENSINO MÉDIO INCOMPLETO         3.278689
# ENSINO FUNDAMENTAL COMPLETO     1.639344
# ENSINO MÉDIO COMPLETO           1.639344
# Name: DS_GRAU_INSTRUCAO, dtype: float64

# %%
perfil_eleitorado_2020 = pd.read_csv("/content/drive/My Drive/Colab Datasets/eleicoes/perfil_eleitorado_2020.csv", sep=';', encoding='iso-8859-1')

# %%
perfil_eleitorado_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248507 entries, 0 to 4248506
# Data columns (total 21 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   DT_GERACAO                  object
#  1   HH_GERACAO                  object
#  2   ANO_ELEICAO                 int64
#  3   SG_UF                       object
#  4   CD_MUNICIPIO                int64
#  5   NM_MUNICIPIO                object
#  6   CD_MUN_SIT_BIOMETRIA        int64
#  7   DS_MUN_SIT_BIOMETRIA        object
#  8   NR_ZONA                     int64
#  9   CD_GENERO                   int64
#  10  DS_GENERO                   object
#  11  CD_ESTADO_CIVIL             int64
#  12  DS_ESTADO_CIVIL             object
#  13  CD_FAIXA_ETARIA             int64
#  14  DS_FAIXA_ETARIA             object
#  15  CD_GRAU_ESCOLARIDADE        int64
#  16  DS_GRAU_ESCOLARIDADE        object
#  17  QT_ELEITORES_PERFIL         int64
#  18  QT_ELEITORES_BIOMETRIA      int64
#  19  QT_ELEITORES_DEFICIENCIA    int64
#  20  QT_ELEITORES_INC_NM_SOCIAL  int64
# dtypes: int64(12), object(9)
# memory usage: 680.7+ MB

# %%
perfil_abstencao = pd.read_csv('/content/drive/My Drive/Colab Datasets/eleicoes/perfil_comparecimento_abstencao_2018.csv', sep=';', encoding='iso-8859-1')

# %%
perfil_abstencao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8362586 entries, 0 to 8362585
# Data columns (total 23 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   DT_GERACAO                     object
#  1   HH_GERACAO                     object
#  2   ANO_ELEICAO                    int64
#  3   NR_TURNO                       int64
#  4   SG_UF                          object
#  5   CD_MUNICIPIO                   int64
#  6   NM_MUNICIPIO                   object
#  7   NR_ZONA                        int64
#  8   CD_GENERO                      int64
#  9   DS_GENERO                      object
#  10  CD_ESTADO_CIVIL                int64
#  11  DS_ESTADO_CIVIL                object
#  12  CD_FAIXA_ETARIA                int64
#  13  DS_FAIXA_ETARIA                object
#  14  CD_GRAU_ESCOLARIDADE           int64
#  15  DS_GRAU_ESCOLARIDADE           object
#  16  QT_APTOS                       int64
#  17  QT_COMPARECIMENTO              int64
#  18  QT_ABSTENCAO                   int64
#  19  QT_COMPARECIMENTO_DEFICIENCIA  int64
#  20  QT_ABSTENCAO_DEFICIENCIA       int64
#  21  QT_COMPARECIMENTO_TTE          int64
#  22  QT_ABSTENCAO_TTE               int64
# dtypes: int64(15), object(8)
# memory usage: 1.4+ GB

# %%
perfil_abstencao['DS_GRAU_ESCOLARIDADE'].value_counts()
# Out:
# ENSINO FUNDAMENTAL INCOMPLETO    1439310
# LÊ E ESCREVE                     1184554
# ENSINO MÉDIO COMPLETO            1181364
# ENSINO FUNDAMENTAL COMPLETO      1024648
# ANALFABETO                       1003138
# ENSINO MÉDIO INCOMPLETO           941846
# SUPERIOR COMPLETO                 869552
# SUPERIOR INCOMPLETO               667612
# NÃO INFORMADO                      50562
# Name: DS_GRAU_ESCOLARIDADE, dtype: int64

# %%
perfil_abstencao['NR_ZONA'].value_counts()
# Out:
# 1      134034
# 8       91640
# 4       83144
# 11      82876
# 5       82058
#         ...
# 395      1928
# 292      1920
# 391      1870
# 309      1586
# 308      1576
# Name: NR_ZONA, Length: 421, dtype: int64
